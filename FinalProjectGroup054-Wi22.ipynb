# %% [markdown]
# # COGS 108 - Final Project (change this to your project's title)

# %% [markdown]
# ## Permissions
#
# Place an `X` in the appropriate bracket below to specify if you would like your group's project to be made available to the public. (Note that student names will be included (but PIDs will be scraped from any groups who include their PIDs).
#
# * [  ] YES - make available
# * [  ] NO - keep private

# %% [markdown]
# # Overview

# %% [markdown]
# *Fill in your overview here*

# %% [markdown]
# # Names
#
# - James Larsen
# - Alejandro Servin
# - Lily Steiner
# - Mayra Trejo
# - Lucy Lennemann

# %% [markdown]
# <a id='research_question'></a>
# # Research Question

# %% [markdown]
# How has the sentiment of the language surrounding Deafness used by popular online news sources (ABC, New York Times, USA Today, The Guardian, Associated Press) changed since the 80s?

# %% [markdown]
# <a id='background'></a>
#
# ## Background & Prior Work

# %% [markdown]
# ### Background

# %% [markdown]
# From the lightbulb and internet [1] to football huddles [2] and morse code [3], Deaf people have been an influential part of American society since its origins. Public sentiment towards the deaf community regarding their rights to access and language has been controversial and polarizing. Before we get into the importance of positive language and representation we must first define some terminology regarding the Deaf community and American Sign Language. You may have noticed that we have been capitalizing the “D” in deaf. As with many cultures, the Deaf community takes pride in their abilities and perseverance in the face of ableism. To establish their status as a cultural group, the deaf and hard-of-hearing(hoh) use “D” deaf when discussing their community and its members. “d” deaf is used to denote the medical/scientific analysis regarding deafness, as well as, a general disconnect from the Deaf community [4]. Within the Deaf community there is the term “Deaf Gain" which “accentuates the benefits of being deaf” [5] instead of focusing on the loss of hearing. One of these gains is the ability to communicate in a loud space through the use of signed language. American Sign Language(ASL) is a form of physically expressed communication used by the Deaf community since the early 1800’s. ASL became officially recognized as a language by the academic community when William Stokoe published Dictionary of American Sign Language on Linguistic Principles in 1965 [6]. The use of ASL has long been regarded by the Deaf community as essential for growth and communication [7], though this same sentiment has not always been the viewpoint of American society. The term “audism” refers to the act of discrimination and separation on the basis of one's ability to hear[8]. Examples of audism include, but are not limited to: refusing to use written communication, prohibiting the use of ASL, refusal of service on the basis of deafness, refusal to hire an ASL interpreter, and not learning to sign for a deaf offspring.
#
# Throughout American history, the deaf and hard of hearing have been labeled many things, such as: deaf and dumb, deaf mute, and hearing impaired. All of these terms carry negative connotations in regards to a person's intellect, speaking ability, and the implication that they could “be better” if they could hear typically. To counteract these implications, the Deaf community now prefers the terms deaf and hard-of-hearing, which refer to their inability to conduct and process sound. It must also be mentioned that the term “mute” is now considered a choice in the Deaf community and not a reflection of one's ability to vocalize. Through their sense of comradery and pride, the Deaf community have been able to experience and accomplish many great strides in terms of disability rights and representation. For example, the passage of the Americans with Disabilities Act (ADA) has been said to have been largely influenced by the media exposure given to the Deaf students of Gallaudet University in 1988 during their Deaf President Now protest [9]. Due to the trail blazed by actress Marlee Matlin, Deaf performers like Nyle Dimarco, Millicent Simmonds from _A Quiet Place_(2018), and Lauren Ridolff in _The Eternals_(2021) have all been hired to portray Deaf characters in a more positive and representative light. Until recently deaf characters were often portrayed by hearing performers as exemplified by Hawkeye in _The Avengers_(2012) and the suspense/thriller _Hush_(2016).
#
# Whether they are viewed as disabled or an inspiration, there’s no denying the impact the Deaf have on American culture. Having proper representation and positive sentiment portrayed to the general public has proven to be beneficial to the accessibility and awareness of the Deaf community. In order to continue along this trajectory of inclusion we decided it would be beneficial to analyze the media rhetoric regarding the Deaf community to gain a better understanding of how representation has changed over time.

# %% [markdown]
# ### Prior Work

# %% [markdown]
# Media platforms have demonstrated both positive and unconscious bias in the deaf community. The sentiment of language carries both negative and positive interpretations through journalistic outlets. This expression of negative opinion can be reflected through fact-based news that can create a discrimination toward underrrepresented groups without that intent.
#
# Deeper into this research, there are studies that are taking the first step to reduce unconscious bias against people with disabilities by focusing on the language being used in mainstream media.
#
# In one study, researchers developed a system that can neutralize ableism in texts such as articles, books and speeches. By doing so, they developed an algorithm that identifies any subjective text and generates new sentence pairs to avoid linguistic ableism [10]. For example, if the algorithm reads “Apparently, she’s confined to a wheelchair,” the invective word would be replaced with the word “uses” to neutralize the statement. Their language database contains 1500 sentence pairs that are from movies scripts, articles, and speech transcripts that are later utilized in a BERT encoder [10]. This NLP system supports automatic identification and alternative writing against disability in text.
#
# It is important to mention, there is no standard framework to identify ableist language, but this study explores the possibility of using a pre-training concurrent model using Wiki Neutrality Corpus (WNC) from the very first generative model that can neutralize biased text. No parallel corpus of alesit language currently exists [10]. However, this study proposes a new framework to include more phrases and words that are non-inclusive of disability by collecting sub categorical text that can be used through albelm or audism language. This study also used human evaluation in their model’s generated sentences to maximize the accuracy and neutrality. Human evaluation with their BERT encoder has helped detect hidden words or phrases that are subcategories of ableism in the media.
#
# In summary, the work presented will allow us to explore the possibilities we could take to analyze the media rhetoric and so called “stigma” creating a communication barrier. The hope is that this influence can create a perspective shift so that online language and behavior that is classified as ableism and audism is not accepted within the social norm. These algorithms are being made to regulate, adjust and eliminate a negative narrative.
#
# It is important to address the attitudes in media outlets towards the deaf community because of the insensibility and draw attention to how it is presented. This small change in mainstream media is powerful and can create conversation on a topic that should not be overlooked.

# %% [markdown]
# ### References (include links):
# - [1] McGlinn, I. (2020, August 12). 14 Deaf and Hard-of-Hearing People Who Changed the World. Ai. Retrieved January 28, 2022, from https://www.ai-media.tv/ai-media-blog/famous-deaf-people-15-deaf-and-hard-of-hearing-people-who-changed-the-world/
# - [2] _Huddle_. Gallaudet University. (2021, February 15). Retrieved January 28, 2022, from https://www.gallaudet.edu/about/huddle/#:~:text=In%201894%2C%20the%20Gallaudet%20football,now%20known%20as%20a%20huddle
# - [3] RIT Libraries. (2021, October 26). Hist 330 Deafness and Technology: Overview. InfoGuides. Retrieved January 28, 2022, from https://infoguides.rit.edu/deaftech#:~:text=Deaf%20inventors%20developed%20the%20TTY,available%20for%20the%20Deaf%20user.
# - [4] Berke, J. (2020, January 8). Self-identification in the Deaf Community. Verywell Health. Retrieved January 28, 2022, from https://www.verywellhealth.com/deaf-culture-big-d-small-d-1046233#:~:text=Definitions,members%20of%20the%20deaf%20community.&text=In%20contrast%2C%20%22big%20D%22,quite%20proud%20to%20be%20Deaf
# - [5] Holcomb, T. K. (2013). Introduction to American Deaf Culture. Oxford University Press. Pg. 308.
# - [6] Dawn Sign Press. (2016, August 17). History of American Sign Language. https://www.dawnsign.com. Retrieved January 28, 2022, from https://www.dawnsign.com/news-detail/history-of-american-sign-language
# - [7] Scheetz, N.A. (2001). Orientation to Deafness.  Allyn & Bacon. Second ed. Pg.23.
# - [8] Merriam-Webster. (n.d.). Audism. In Merriam-Webster.com dictionary. Retrieved January 28, 2022, from https://www.merriam-webster.com/dictionary/audism
# - [9] _Deaf President Now_ - Impact. Gallaudet University. (2021, January 12). Retrieved January 28, 2022, from https://www.gallaudet.edu/about/history-and-traditions/deaf-president-now/impact/
# - [10] Liu, T.T., & Shibata, T. (2021). Automatically Neutralizing Ableist Language in Text

# %% [markdown]
# # Hypothesis

# %% [markdown]
# We think that the language surrounding Deafness will have grown more positive since the 80s. This is because cultural awareness of Deaf culture has increased and there has been more representation of Deaf hands in media, sports, and education.

# %% [markdown]
# # Dataset(s)

# %% [markdown]
# We got our datasets by scraping public APIs for news sources. We queried the APIs for articles related to deafness. The APIs would return a list of URLs for articles related to our search. We then would scrape the article text and other relevant information from the URL's website.
#
# __AP News Articles, ABC News Articles, USA Today Articles__
# - datasets/ap_data.json and datasets/abc_data.json, datasets/usa_data.json
# - These datasets were made by getting article URLs from the Google Custom Search API and then scraping the articles from their news sites
#     - https://developers.google.com/custom-search/v1/introduction
# - 380 AP articles, 160 ABC articles, 1300 USA Today articles
#
# __New York Times Articles__
# - datasets/nyt_data.json
# - This dataset was made by getting article URLs from the NYT API and then scraping the articles from the NYT site
#     - https://developer.nytimes.com/
# - 750 articles
#
# __The Guardian Articles__
# - datasets/guard_data.json
# - This dataset was made by getting article URLs from The Guardian API and then scraping the articles from The Guardian website
#     - https://open-platform.theguardian.com/
# - 7000 articles
#
# These datasets should be easy to combine due to us collecting the same information for each article. The information we collected was the news source, the URL, the headline, the publishing date, and the article text.

# %% [markdown]
# # Setup

# %% [markdown]
# Here we import all of the packages necessary to visualize, clean, vectorize,  plot, and analyze the data that we scraped from the news articles.

# %%
import sys
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import json
import unicodedata
import nltk
from textblob import TextBlob, Word
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import stopwords
nltk.download('stopwords')
nltk.download('omw-1.4')
from datetime import date
from collections import defaultdict
import math
import gensim
from gensim import corpora
import string
from sklearn.feature_extraction.text import TfidfVectorizer
# Out:
# [nltk_data] Downloading package stopwords to /home/jamie/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/jamie/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %% [markdown]
# Now that we have the packages we need, we can pull the data we need. The data we have is locally stored in the repo. The results of our API queries are stored in JSON file format.
#
# These JSON files contain a list of JSON objects, where each JSON object represents a single article. The object will contain a headline, a date (string), the source of the article, the url of the article, as well as the article text.
#
# Here we can use pandas to read those JSON files and convert them to DataFrames.

# %%
abc_df = pd.read_json('dataset/abc_data.json')
ap_df = pd.read_json('dataset/ap_data.json') 
guard_df = pd.read_json('dataset/guard_data.json')
nyt_df = pd.read_json('dataset/nyt_data.json') 
usa_df = pd.read_json('dataset/usa_data.json')

# %% [markdown]
# Set dataframe row and column display

# %%
pd.options.display.max_rows=6
pd.options.display.max_columns=5
#pd.options.display.max_colwidth=40

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# The data that we scraped is messy, and so we want to create a function to help us clean our data and get it into a standardized format. We want this function to do a number of things.
#
# #### Define a dataframe cleaning function that:
# - Renames the columns
# - Drops null values
# - Renames the source strings to their acronyms
# - Converts the date strings to pd.datetime format
# - Translate unicode artifacts from the text using unicodedata.normalize
#
# We want the columns to be renamed for easier access later in the notebook, and similarly we want the news sources to be renamed to their acronyms for similar ease of use. We want to drop null values so that we aren't working with any incomplete data. We want to convert our date strings into a format that is easier to work with. And finally we want to translate any unicode artifacts that are left over from scraping the articles off of a website into their plaintext equivalents.

# %%
def df_clean(df, source):
    df = df[['headline','date','source','url','text']]
    
    df.dropna(inplace=True)
        
    df['source'] = source

    df['date'] = pd.to_datetime(df['date'])
    df = df[~(df['date']<='1980-01-01')]
    
    df['text'] = df['text'].apply(lambda t: unicodedata.normalize('NFKD', t))
        
    return df

# %% [markdown]
# #### Apply function and visualize cleaned dataframes.

# %% [markdown]
# #### ABC News Dataframe

# %%
abc_df = df_clean(abc_df, 'abc')
abc_df.head()
# Out:
#                                             headline                date  \
# 0  Prosecutor: Alex Murdaugh now faces 71 charges... 2022-01-21 18:17:00
# 1  Undefeated: Deaf football team brings triumph ... 2021-11-20 12:59:00
# 2  Referee accused of discriminating against deaf... 2021-12-30 02:53:00
# 3  Preserving Black American Sign Language in the... 2021-02-18 19:49:00
# 4  Baby born deaf has touching reaction to hearin... 2021-03-02 01:32:00
#
#   source                                                url  \
# 0    abc  https://abcnews.go.com/US/wireStory/prosecutor...
# 1    abc  https://abcnews.go.com/US/undefeated-deaf-foot...
# 2    abc  https://abcnews.go.com/US/referee-accused-disc...
# 3    abc  https://abcnews.go.com/US/preserving-black-ame...
# 4    abc  https://abcnews.go.com/US/baby-born-deaf-touch...
#
#                                                 text
# 0  COLUMBIA, S.C. -- A once-prominent South Carol...
# 1  Once considered underdogs, the football team a...
# 2  The American Civil Liberties Union is accusing...
# 3  Fifty-eight years after Martin Luther King Jr....
# 4  After months of appointments, testing, fitting...

# %% [markdown]
# #### Associated Press dataframe

# %% [markdown]
# Of the 380 AP articles we have in our dataset, 120 of them are articles that are reporting the scores of highschool basketball games. They were pulled into the dataset due to some of the schools having Deaf in their name (Tucson School-Deaf and Blind). These articles don't have any useful information, so we will drop them from our dataset.

# %%
# Removing highschool scores from AP's articles
ap_df = ap_df[ap_df['headline'].str.contains("Monday's Scores|Tuesday's Scores|Wednesday's Scores|Thursday's Scores|Friday's Scores|Saturday's Scores|Sunday's Scores")==False]

# %%
ap_df = df_clean(ap_df, 'ap')
ap_df.head()
# Out:
#                                              headline  \
# 0   2 hurt when part of student center collapses a...
# 1   Georgia hospital agrees to measures to help de...
# 3   New NYC mayor says kids safe in school despite...
# 36  Mickey Guyton, Jhené Aiko, Mary Mary to sing a...
# 37  Omicron surge is undermining care for other he...
#
#                         date source  \
# 0  2022-01-13 12:53:56+00:00     ap
# 1  2022-01-09 15:58:08+00:00     ap
# 3  2022-01-03 17:06:08+00:00     ap
# 36 2022-02-01 16:30:05+00:00     ap
# 37 2022-01-21 16:00:39+00:00     ap
#
#                                                   url  \
# 0   https://apnews.com/article/lifestyle-alabama-a...
# 1   https://apnews.com/article/georgia-us-departme...
# 3   https://apnews.com/article/coronavirus-pandemi...
# 36  https://apnews.com/article/sports-entertainmen...
# 37  https://apnews.com/article/coronavirus-pandemi...
#
#                                                  text
# 0   TALLADEGA, Ala. (AP) — Two workers were injure...
# 1   CALHOUN, Ga. (AP) — Federal authorities have r...
# 3   NEW YORK (AP) — New York City schoolchildren r...
# 36  LOS ANGELES (AP) — Country music star Mickey G...
# 37  Roger Strukhoff was being treated for intestin...

# %% [markdown]
# #### The Guardian Dataframe

# %%
guard_df = df_clean(guard_df, 'guard')
guard_df.head()
# Out:
#                                             headline  \
# 0  British Sign Language to become recognised lan...
# 1  Scottish health board apologises over late dia...
# 2  Strictly: sign language interpreter to be proj...
# 3  Audible review – American football film makes ...
# 4  ‘Why can’t I give it a go?’: How Rose Ayling-E...
#
#                        date source  \
# 0 2022-01-27 19:51:16+00:00  guard
# 1 2021-12-09 18:10:02+00:00  guard
# 2 2022-01-10 17:36:39+00:00  guard
# 3 2021-07-02 05:00:29+00:00  guard
# 4 2021-12-18 09:00:53+00:00  guard
#
#                                                  url  \
# 0  https://www.theguardian.com/society/2022/jan/2...
# 1  https://www.theguardian.com/society/2021/dec/0...
# 2  https://www.theguardian.com/tv-and-radio/2022/...
# 3  https://www.theguardian.com/tv-and-radio/2021/...
# 4  https://www.theguardian.com/society/2021/dec/1...
#
#                                                 text
# 0  British Sign Language (BSL) is on course to be...
# 1  A Scottish health board has apologised for “ho...
# 2  She was the first deaf contestant and winner o...
# 3  Ten years ago, director Matt Ogens was shootin...
# 4  Amid all the noise, glitter and razzle-dazzle,...

# %% [markdown]
# #### The New York Times Dataframe

# %% [markdown]
# Old New York Times articles weren't manually transcribed, but instead were put online using software to lift the article text from pictures of old news prints. All of these older articles contain a warning at the beginning of the article informing the reader that they may have inaccuracies due to the transcription software. These warnings aren't useful to our data analysis and so can be removed from the article text.
#
# The NYT articles were also littered with odd remnants of CSS that were picked up while scraping. These remnants are always enclosed by squiggly braces, so we can go through the article text and remove any bits of it enclosed in those braces.

# %%
# Removing the archive heading from NYT articles
nyt_df['text'] = nyt_df['text'].str.replace('Credit...The New York Times Archives.*improve these archived versions.', '', regex=True)

# Removing weird formatting stuff from NYT articles
nyt_df['text'] = nyt_df['text'].str.replace('{.*?}', '', regex=True)

# %%
nyt_df = df_clean(nyt_df, 'nyt')
nyt_df.head()
# Out:
#                                             headline  \
# 0  How the Beatles Broke Up and the Deaf Football...
# 1                         Don’t Fear a Deafer Planet
# 2  R. Allen Gardner, 91, Dies; Taught Sign Langua...
# 3  Barbara Kannapell, Activist Who Empowered Deaf...
# 4  Lesson of the Day: ‘Black, Deaf and Extremely ...
#
#                        date source  \
# 0 2021-11-19 10:30:02+00:00    nyt
# 1 2021-10-10 15:00:07+00:00    nyt
# 2 2021-10-01 16:37:51+00:00    nyt
# 3 2021-08-21 17:14:46+00:00    nyt
# 4 2021-01-29 09:00:06+00:00    nyt
#
#                                                  url  \
# 0  https://www.nytimes.com/2021/11/19/podcasts/th...
# 1  https://www.nytimes.com/2021/10/10/opinion/dea...
# 2  https://www.nytimes.com/2021/10/01/science/r-a...
# 3  https://www.nytimes.com/2021/08/21/us/barbara-...
# 4  https://www.nytimes.com/2021/01/29/learning/le...
#
#                                                 text
# 0  This weekend, listen to a collection of narrat...
# 1  In Deaf culture, we have a rich storytelling t...
# 2  Washoe was 10 months old when her foster paren...
# 3  Barbara Kannapell, a world-renowned deaf activ...
# 4  Students in U.S. high schools can get free dig...

# %% [markdown]
# #### USA Today dataframe

# %% [markdown]
# The date pulled from the USA Today articles is in a wonky format. Instead of being in a normal date format, the date field in the database includes both a published date and a date on which the article was updated. We are interested in the date the article was published, so we want to extract that date in particular from the date field and convert it to the proper format.

# %%
usa_df['date'] = usa_df['date'].str.extract(r'Published:? (.*?)(?:Updated:?.*)?$')

# %% [markdown]
# We're adding some extra code to temporarily disable the chained assignment warning, because it dives an unneeded warning for our cleaning function. This is because of the date manipulation code we added above for this dataset.

# %%
pd.options.mode.chained_assignment = None
usa_df = df_clean(usa_df, 'usa')
pd.options.mode.chained_assignment = 'warn'

usa_df.head()
# Out:
#                                             headline                date  \
# 0  Deaf Detroit rapper to join Eminem, Dre, Snoop... 2022-02-04 20:16:00
# 1  Black, deaf, proud: Gallaudet University embra... 2022-02-03 05:01:00
# 2  Reviewed launches new vertical dedicated to ac... 2022-01-10 08:58:00
# 3  Deer as pets: Rare piebald deer find home with... 2022-01-06 12:39:00
# 4  Man finds cockroach in ear after swimming in N... 2022-01-13 14:01:00
#
#   source                                                url  \
# 0    usa  https://www.usatoday.com/story/entertainment/m...
# 1    usa  https://www.usatoday.com/story/news/nation/202...
# 2    usa  https://www.usatoday.com/story/money/reviewed/...
# 3    usa  https://www.usatoday.com/story/news/nation/202...
# 4    usa  https://www.usatoday.com/story/news/world/2022...
#
#                                                 text
# 0  Sean Forbes had expected to experience this ye...
# 1  WASHINGTON – It’s a chilly December day on the...
# 2  — Recommendations are independently chosen by ...
# 3  STROUDSBURG, Pa. — While many families enjoy c...
# 4  A man who thought his ear was blocked from wat...

# %% [markdown]
# #### Combined dataframe

# %% [markdown]
# Now that we have individually cleaned all of the datasets, we can combine them into a single unified dataframe in order to easily manipulate it later.

# %%
df_list = [abc_df, ap_df, guard_df, nyt_df, usa_df]
combined_df = pd.concat(df_list).reset_index(drop=True)
combined_df.head()
# Out:
#                                             headline                 date  \
# 0  Prosecutor: Alex Murdaugh now faces 71 charges...  2022-01-21 18:17:00
# 1  Undefeated: Deaf football team brings triumph ...  2021-11-20 12:59:00
# 2  Referee accused of discriminating against deaf...  2021-12-30 02:53:00
# 3  Preserving Black American Sign Language in the...  2021-02-18 19:49:00
# 4  Baby born deaf has touching reaction to hearin...  2021-03-02 01:32:00
#
#   source                                                url  \
# 0    abc  https://abcnews.go.com/US/wireStory/prosecutor...
# 1    abc  https://abcnews.go.com/US/undefeated-deaf-foot...
# 2    abc  https://abcnews.go.com/US/referee-accused-disc...
# 3    abc  https://abcnews.go.com/US/preserving-black-ame...
# 4    abc  https://abcnews.go.com/US/baby-born-deaf-touch...
#
#                                                 text
# 0  COLUMBIA, S.C. -- A once-prominent South Carol...
# 1  Once considered underdogs, the football team a...
# 2  The American Civil Liberties Union is accusing...
# 3  Fifty-eight years after Martin Luther King Jr....
# 4  After months of appointments, testing, fitting...

# %% [markdown]
# # Data Analysis & Results

# %% [markdown]
# ## Generating Sentiment Analysis Scores

# %% [markdown]
# In this next section, we are creating new dataframes which will have the analysis results in addition to defining a few helper functions for our analysis.

# %% [markdown]
# Define a funciton that finds sentiment within a given text

# %%
def get_sentiment(text):
    blob = TextBlob(text)
    polarity, subjectivity = blob.sentiment
    return polarity, subjectivity

# %% [markdown]
# Now we will apply this function to each news dataframe and add two columns with the objectivity score and subjectivity score (polarity ranging from -1 to 1 and subjectivity from 0 to 1)

# %%
combined_df[['polarity', 'subjectivity']] = combined_df.apply(lambda x: get_sentiment(x['text']),
                                                              axis=1, result_type='expand')

# %% [markdown]
# We're now combining all the different dataframe into one unified dataframe. We're also making a column specifically for the year in which the article was published for easier graphing.

# %%
combined_df['year'] = combined_df['date'].apply(lambda d: d.year)
combined_df.head()
# Out:
#                                             headline                 date  \
# 0  Prosecutor: Alex Murdaugh now faces 71 charges...  2022-01-21 18:17:00
# 1  Undefeated: Deaf football team brings triumph ...  2021-11-20 12:59:00
# 2  Referee accused of discriminating against deaf...  2021-12-30 02:53:00
# 3  Preserving Black American Sign Language in the...  2021-02-18 19:49:00
# 4  Baby born deaf has touching reaction to hearin...  2021-03-02 01:32:00
#
#    ... subjectivity  year
# 0  ...     0.394252  2022
# 1  ...     0.488425  2021
# 2  ...     0.421270  2021
# 3  ...     0.389587  2021
# 4  ...     0.528889  2021
#
# [5 rows x 8 columns]

# %% [markdown]
# Checking to see how many articles we have per year

# %%
plt.rcParams['figure.figsize'] = (17, 15)

sns.countplot(data=combined_df, x='year')
# Out:
# <AxesSubplot:xlabel='year', ylabel='count'>

# %% [markdown]
# We'll have to keep in mind that our data is much denser for 1999 onwards than for 1981-1998

# %% [markdown]
# ## Overview of Sentiment Analysis Results

# %% [markdown]
# Barplot showing the average polarity scores and sentiments by news source. USA is the most positive in terms of polarity. Overall, we can see a slightly positive sentiment. In terms of subjectivity, we can see that for the most part all the sources are on the more objective side since they are less than 0.5, with Gaurdian being the most subjective.

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 5))
fig.suptitle('Average polarity and subjectivity by news source')
axes[1].set_title('Subjectivity')
axes[0].set_title('Polarity')
sns.barplot(ax=axes[1],x=combined_df['source'], y=combined_df['subjectivity'])
sns.barplot(ax=axes[0],x=combined_df['source'], y=combined_df['polarity'])
# Out:
# <AxesSubplot:title={'center':'Polarity'}, xlabel='source', ylabel='polarity'>

# %% [markdown]
#  Visualization of the distribution of polarity vs subjectivity. We see a few outliers, mostly from USA. Generally we can see the overall trend again of our articles having a more positive sentiment and being less subjective.

# %%
sns.scatterplot(data=combined_df[combined_df['year'] >= 2008], x='subjectivity', y='polarity', hue='source')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)

# %% [markdown]
# Next we will look at this data over time. The following are lineplots showing the polarity and sentiment over time for each news source.

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 5))
fig.suptitle('polarity and subjectivity by news source over time')
axes[1].set_title('Subjectivity')
axes[0].set_title('Polarity')
sns.lineplot(ax=axes[0], data=combined_df, x='year', y='polarity', hue='source', ci=None)
sns.lineplot(ax=axes[1], data=combined_df, x='year', y='polarity', hue='source', ci=None)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)

# %% [markdown]
# Since some of our news sources don't have articles as far back, we'll take a closer look with the minimum year being 2008.

# %%
sns.lineplot(data=combined_df[combined_df['year'] >= 2008], x='year', y='polarity', hue='source', ci=None)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)

# %% [markdown]
# Some of these years have scores are relatively low in comparison, so we will investigate these. First we will look at the 1990 AP and Guardian articles from the previous figure. Next we will explore the dip in ABC, NYT, and USA in 2013.

# %%
#investigate dips in 1990 AP and guard articles:
pd.set_option("display.max_rows", None, "display.max_columns", None)
pd.options.display.max_colwidth = 130
combined_df[(combined_df['year'] == 1990) & ((combined_df['source'] == 'ap') | (combined_df['source'] == 'guard'))]
# Out:
#                                                                     headline  \
# 410           ANOTHER LOOK: White Supremacist Posse Comitatus Fades Into ...
# 411   Blind Lobby for Bill to Ban Seating Limitations on Airliners | AP News
# 7249                                                Yours sincerely, FG Pink
#
#                            date source  \
# 410   1990-09-10 04:07:00+00:00     ap
# 411   1990-02-07 07:41:00+00:00     ap
# 7249  1990-04-11 01:07:37+00:00  guard
#
#                                                                             url  \
# 410                 https://apnews.com/article/f11b9a11163961c6a81666e4dfdc1625
# 411                 https://apnews.com/article/7bd22eafb2685016dd201f62fdf22bea
# 7249  https://www.theguardian.com/society/1990/apr/11/guardiansocietysupplement
#
#                                                                                                                                    text  \
# 410   \t   TIGERTON, Wis. (AP) _ Delbert Larson scanned the empty woods where the Posse Comitatus once envisioned a paramilitary set...
# 411   \t   WASHINGTON (AP) _ Scores of blind people are lobbying Congress to overturn a proposed Federal Aviation Administration rul...
# 7249  At the age of 60, when other men would be winding down or already retired, he is not only working 11 1/2-hour night shifts, bu...
#
#       polarity  subjectivity  year
# 410  -0.033320      0.442262  1990
# 411  -0.084977      0.477494  1990
# 7249  0.014540      0.490090  1990

# %% [markdown]
# Looking at the following articles, it makes sense there was a low sentiment for each. One discusses an ableist bill being passed by Congress, and the others use ableist language with respect to the Deaf community. There is only one article from the Guardian and 2 from AP for this year, which limits the ability to make a generalized statement about the sentiment surrounding the Deaf community during this era. Considering that these are the only articles we have for this year by these two sources, and all are negatively related to the Deaf, it would be good to consider this moving forward in terms of our research question.

# %% [markdown]
# Lets explore the dip in ABC, NYT, and USA in 2013.

# %%
#~2013 NYT and ABC and USA
pd.set_option("display.max_rows", None, "display.max_columns", None)
pd.options.display.max_colwidth = 130
#get a subset of all articles from these specific news sources that have a less than 0 polarity from the year 2013
combined_df[(combined_df['polarity'] < 0) & (combined_df['year'] == 2013) & ((combined_df['source'] == 'nyt') | (combined_df['source'] == 'usa') | (combined_df['source'] == 'abc'))]
# Out:
#                                                               headline  \
# 127   Deaf Man Stabbed After Sign Language Mistaken for Gang Signs ...
# 129           Deaf Texas Parents Allegedly Kill Crying Baby - ABC News
# 7695                                       Art Comes to the Interstate
# 7697                                       Nebraska: Deaf Student Wins
# 7699            Deaf Patrons’ Suit Accuses Starbucks of Discrimination
# 9235               WH: No comment on Obama's sign language interpreter
# 9236              Mandela memorial interpreter used bogus signs before
# 9240                    Interpreter at Mandela memorial branded 'fake'
# 9246            Deaf man stabbed when sign language seen as gang signs
# 9248        Report: S. African interpreter charged with murder in 2003
# 9254            S. Africa investigates sign interpreter's violent past
# 9265        Mandela event signer was in group that burned men to death
# 9270                             5 things you need to know on Thursday
# 9271         Vocalist Billy Bowers of Blind Boys of Alabama dead at 71
# 9273                                       High school results, Dec. 5
# 9275         Nev. hospitals accused of shipping mentally ill to Calif.
# 9311                                      High school results Sept. 11
#
#                            date source  \
# 127         2013-01-14 20:21:00    abc
# 129         2013-05-01 14:20:00    abc
# 7695  2013-09-24 14:30:18+00:00    nyt
# 7697  2013-09-05 03:57:00+00:00    nyt
# 7699  2013-08-08 21:07:41+00:00    nyt
# 9235        2013-12-11 12:47:00    usa
# 9236        2013-12-12 04:06:00    usa
# 9240        2013-12-11 06:21:00    usa
# 9246        2013-01-11 20:06:00    usa
# 9248        2013-12-13 10:35:00    usa
# 9254        2013-12-13 09:41:00    usa
# 9265        2013-12-16 08:20:00    usa
# 9270        2013-12-12 02:55:00    usa
# 9271        2013-07-16 07:36:00    usa
# 9273        2013-12-05 23:18:00    usa
# 9275        2013-08-21 14:58:00    usa
# 9311        2013-09-12 07:08:00    usa
#
#                                                                                                                                   url  \
# 127                                    https://abcnews.go.com/US/deaf-man-stabbed-sign-language-mistaken-gang-signs/story?id=18213488
# 129                                         https://abcnews.go.com/US/deaf-texas-parents-allegedly-kill-crying-baby/story?id=19082627
# 7695                                              https://tmagazine.blogs.nytimes.com/2013/09/24/on-view-art-comes-to-the-interstate/
# 7697                                                            https://www.nytimes.com/2013/09/05/us/nebraska-deaf-student-wins.html
# 7699          https://www.nytimes.com/2013/08/09/nyregion/suit-accuses-new-york-starbucks-of-discriminating-against-deaf-patrons.html
# 9235  https://www.usatoday.com/story/theoval/2013/12/11/obama-sign-language-interpreter-south-africa-nelson-mandela-memorial/3987539/
# 9236                https://www.usatoday.com/story/news/world/2013/12/12/mandela-sign-language-interpreter-thamsanqa-jantjie/3995875/
# 9240                                     https://www.usatoday.com/story/news/world/2013/12/11/mandela-south-africa-deaf-fake/3985257/
# 9246                                                  https://www.usatoday.com/story/news/nation/2013/01/11/deaf-man-stabbed/1828077/
# 9248                             https://www.usatoday.com/story/news/world/2013/12/13/south-africa-sign-language-interpreter/4009717/
# 9254                             https://www.usatoday.com/story/news/world/2013/12/13/s-africa-investigates-sign-interpreter/4008999/
# 9265                  https://www.usatoday.com/story/news/world/2013/12/16/mandela-event-signer-was-in-group-that-burned-men/4037851/
# 9270                                      https://www.usatoday.com/story/news/nation/2013/12/12/five-things-to-know-thursday/3991167/
# 9271                           https://www.usatoday.com/story/news/nation/2013/07/16/billy-bowers-boys-of-alabama-dead-at-71/2520119/
# 9273                                         https://www.usatoday.com/story/hs-scores/2013/12/06/high-school-results-dec-5-2/3887363/
# 9275                                 https://www.usatoday.com/story/news/nation/2013/08/21/nevada-california-patient-dumping/2681593/
# 9311                                       https://www.usatoday.com/story/hs-scores/2013/09/12/high-school-results-sept-11-2/2802543/
#
#                                                                                                                                    text  \
# 127   Jan 14, 2013— -- A deaf man in North Carolina, communicating to a friend via sign language, was stabbed multiple times after h...
# 129   May 1, 2013 — -- A deaf Texas couple have been charged in the beating death of their 5-month-old daughter who was allegedly ki...
# 7695  \n                            \n                                A detail from Shana Lutker’s series “Onward and Upward,” for M...
# 7697   Creighton University violated the Americans with Disabilities Act and the Rehabilitation Act when it failed to provide accomm...
# 7699  The Starbucks coffee shop on Astor Place is an airy, communal retreat where the regulars huddle with their laptops, reconnect ...
# 9235  The White House is declining to comment on reports in South Africa that the man who provided alleged sign interpretation of Pr...
# 9236  Thamsanqa Jantjie says he suffered schizophrenic episodeSouth Africa is investigating the allegationsJantjie was paid %2485 to...
# 9240  Government is investigating the allegationPRETORIA, South Africa -- The sign language interpreter used at Tuesday's memorial s...
# 9246  The victim is in stable condition.He was stabbed several times with a kitchen knifeHis attacker faces multiple charges includi...
# 9248  The South African government says it is investigating the 'fake' sign language interpreter at Nelson Mandela's memorial, accor...
# 9254  Asked by AP reporter about a murder charge%2C Jantjie turned and walked away without commentingU.S. officials are concerned ab...
# 9265  Jantjie%27s friends%2C relative say he was with a group that assaulted two men found with a stolen TV in 2003The group put tir...
# 9270  Cell phones on planes hearing todayThe Federal Communications Commission will officially start to debate today whether or not ...
# 9271  Billy Bowers was a member of the Blind Boys singing group as well as an evangelist and radio announcerBowers performed with th...
# 9273  BOYS BASKETBALLTHURSDAY'S SCORESBaptist Academy 102, Crosspointe Christian 48Indiana Deaf 54, Bethesda Christian 41Traders Poi...
# 9275  San Francisco said it spent nearly %24500%2C000 on care for patients improperly bused from NevadaThe practice apparently has b...
# 9311  BOYS CROSS COUNTRYGreenfield Central InvitationalTeam scores:Greenfield Central 40, Warren Central 44, Roncalli 46, Scecina 13...
#
#       polarity  subjectivity  year
# 127  -0.125427      0.298504  2013
# 129  -0.083373      0.329059  2013
# 7695 -0.100000      0.347619  2013
# 7697 -0.166667      0.433333  2013
# 7699 -0.030246      0.418780  2013
# 9235 -0.054545      0.362626  2013
# 9236 -0.072412      0.502418  2013
# 9240 -0.186667      0.586528  2013
# 9246 -0.087037      0.129630  2013
# 9248 -0.134783      0.414130  2013
# 9254 -0.167857      0.490476  2013
# 9265 -0.065000      0.155000  2013
# 9270 -0.043794      0.533842  2013
# 9271 -0.044939      0.578707  2013
# 9273 -0.002545      0.126182  2013
# 9275 -0.008172      0.313358  2013
# 9311 -0.015455      0.240032  2013

# %% [markdown]
# Looking at these results, one commmon thing we can observe is that the event where an unqualified sign interpreter was present at a memorial for Nelson Mandela has an overall low polarity score and is the subject of many of these articles (6 total)

# %% [markdown]
# ### Looking for outliers

# %% [markdown]
# With the following graphs, we graphed the distribution of the variable polarity separated by news source. The polarity represents the degree of sentiment from -1 to 1, -1 being very negative and 1 being very positive. We also included a dotted line to indicate the mean of each distribution.

# %%
# AP news
plt.subplot(2, 3, 1)
graph1 = sns.histplot(data=ap_df, x='polarity')
graph1.set_title("AP News Polarity")
graph1.axvline(ap_df['polarity'].mean(), color='#2e2e2e', linestyle='--')

# the Guardian
plt.subplot(2, 3, 2)
graph2 = sns.histplot(data=guard_df, x='polarity')
graph2.set_title('Guardian News Polarity')
graph2.axvline(guard_df['polarity'].mean(), color='#2e2e2e', linestyle='--')

# NY Times
plt.subplot(2, 3, 3)
graph3 = sns.histplot(data=nyt_df, x='polarity')
graph3.set_title('New York Times Polarity')
graph3.axvline(nyt_df['polarity'].mean(), color='#2e2e2e', linestyle='--')

# USA Today
plt.subplot(2, 3, 4)
graph4 = sns.histplot(data=usa_df, x='polarity')
graph4.set_title('USA Today Polarity')
graph4.axvline(usa_df['polarity'].mean(), color='#2e2e2e', linestyle='--')

# ABC News
plt.subplot(2, 3, 5)
graph5 = sns.histplot(data=abc_df, x='polarity')
graph5.set_title('ABC News Polarity')
graph5.axvline(abc_df['polarity'].mean(), color='#2e2e2e', linestyle='--')

# %% [markdown]
# Next, we take a look at the outliers in the graph for each news source and remove the articles that are irrelevant for our research question.

# %%
# the Guardian: filter dataset by the outliers that can be seen on the graph
guard_df[(guard_df['polarity'] > 0.4) | (guard_df['polarity'] < -0.2)]
# Out:
#                                                      headline  \
# 2479                  Wonderstruck by Brian Selznick - review
# 2887              Computer learns to understand sign language
# 3719                             Pick of the week: Rock & pop
# 3852                      Books preview: David Lodge, Norwich
# 6661  A thousand years packed into a long weekend in Anglesey
#
#                           date source  \
# 2479 2013-01-06 09:00:00+00:00  guard
# 2887 2009-07-10 10:00:00+00:00  guard
# 3719 2009-04-03 23:01:00+00:00  guard
# 3852 2008-10-03 23:12:06+00:00  guard
# 6661 2000-01-02 00:50:22+00:00  guard
#
#                                                                                                   url  \
# 2479  https://www.theguardian.com/childrens-books-site/2013/jan/06/review-wonderstruck-brian-selznick
# 2887                   https://www.theguardian.com/technology/blog/2009/jul/10/computer-sign-language
# 3719                             https://www.theguardian.com/culture/2009/apr/04/north-pop-rock-picks
# 3852                                 https://www.theguardian.com/culture/2008/oct/04/centrallistings1
# 6661                                    https://www.theguardian.com/world/2000/jan/02/millennium.uk13
#
#                                                                                                                                    text  \
# 2479  This book is about a boy called Ben who lives in Minnesota. He is deaf in one ear and lives with his uncle and aunt. He goes l...
# 2887  A woman signing the wood 'good'. Photograph: Turbo/zefa/CorbisHere's something for anyone whose parents ever told them they wo...
# 3719  David Byrne Sheffield City Hall, Sat 4 AprQuesting Talking Heads oddball and world music proselytiser revisits his collaborati...
# 3852  The writer will talk about his life and work, including his latest novel, Deaf Sentence. Followed by book signing. 7pm, Lectur...
# 6661  We left London with nothing more than a road map, a change of pants, and a suitcase packed with the best things of the past 1,...
#
#       polarity  subjectivity
# 2479 -0.296875      0.625000
# 2887  0.406061      0.675758
# 3719  0.500000      0.575000
# 3852  0.500000      0.900000
# 6661  0.429016      0.540688

# %%
# content seems irrelevant to our discussion of Deaf representation in the media
guard_df.loc[3719, 'text']
# Out:
# "David Byrne Sheffield City Hall, Sat 4 AprQuesting Talking Heads oddball and world music proselytiser revisits his collaborations with Brian Eno, including recent one Everything That Happens Will Happen Today.Bat For Lashes The Ritz, Manchester, Tue 7; Northumbria University Students' Union, Newcastle upon Tyne, Thu 9 Apr Hypnotic folk pop from the multi-instrumentalist and artist. Welcome to kooksville.Fujiya & Miyagi Cargo, London, Wed 8; The Faversham, Leeds, Thu 9; The Deaf Institute, Manchester, Fri 10 Apr Arch but infectious, built on krautrock and venturing somewhere like a space disco. Ace!"

# %%
# another irrelevant outlier to remove
guard_df.loc[3852, 'text']
# Out:
# 'The writer will talk about his life and work, including his latest novel, Deaf Sentence. Followed by book signing. 7pm, Lecture theatre 1, University of East Anglia, Norwich. Tickets £6. Tel 01603 508050.'

# %%
# remove rows 3719, 3852 after looking at the text and deciding it's irrelevant
guard_df = guard_df.drop(3719)
guard_df = guard_df.drop(3852)

# %% [markdown]
# In USA Today, we also noticed some irrelevant outliers that we decided to remove.

# %%
# USA Today
usa_df[(usa_df['polarity'] < -0.5) | (usa_df['polarity'] > 0.6)]
# Out:
#                                                              headline  \
# 523   Prep basketball: Top performers in girls high school basketball
# 624                        125 pets get a new leash on life in Oregon
# 1192                                          IC preschool graduation
#
#                     date source  \
# 523  2018-01-27 12:42:00    usa
# 624  2018-09-08 19:53:00    usa
# 1192 2014-06-01 16:29:00    usa
#
#                                                                                                                           url  \
# 523   https://www.usatoday.com/story/sports/high-school/2018/01/27/top-performers-girls-basketball-knoxville-area/1071278001/
# 624                             https://www.usatoday.com/story/news/2018/09/08/125-pets-get-new-leash-life-oregon/1240205002/
# 1192                                          https://www.usatoday.com/story/news/2014/06/01/ic-preschool-graduation/9842891/
#
#                                                                                                                                    text  \
# 523   Destiny Haworth, Alcoa: Haworth scored 14 points in the 58-28 win against Scott County.Katie Bean, Alcoa: Bean had a double-do...
# 624   A mother terrier with her litter of five-day-old puppies and a deaf dog named Hazel were among the 108 dogs and 17 cats that a...
# 1192  PORT CLINTON – Students in the preschool program at Immaculate Conception School Preschool graduated.Under the direction of Ma...
#
#       polarity  subjectivity
# 523   0.687879      0.377778
# 624  -0.875000      1.000000
# 1192  0.675000      0.775000

# %%
# we are not considering sports news as part of our data
usa_df.loc[523, 'text']
# Out:
# 'Destiny Haworth, Alcoa: Haworth scored 14 points in the 58-28 win against Scott County.Katie Bean, Alcoa: Bean had a\xa0double-double with 12 points 10 rebounds in the 37-32 loss to Fulton.Maci Houser, Anderson County: Houser scored 12 points in the 59-25 loss to Oak Ridge.Larriana Bullard, Austin-East: Bullard scored 21 points in the 48-37 loss to Kingston.Trinity Lee, Bearden: Lee scored\xa015 points in the 55-12 win over West.Evie DePetro, Carter: DePetro scored 11 points eight\xa0assists and three steals in the 64-49 win over Union County.Sarah Irwin, Carter: Irwin scored 13 points, 17 rebounds, four\xa0assists and two\xa0steals in the win over Union County.Zarria Clark, Carter: Clark scored 10 points and had seven\xa0rebounds in the win against Union County.Megan Miller, Cosby: Miller scored 19 points in the 59-15 win over Tennessee School for the Deaf.\xa0Gracee Dishman, Cumberland County: Dishman scored 38 points in the 76-51 win against Grundy.Kiara Wilson, Cumberland County: Wilson scored 15 points in the win against Grundy.Lay Lay Manning, Fulton: Manning scored 16 points in the 37-32 win over Alcoa.Cassie Peters,\xa0Grace Christian: Peters scored\xa018 points and had five\xa0steals with four\xa0assists in the 71-18 win against First Baptist Academy.Panda Riggs, Halls: Riggs scored 14 points in the 44-37 loss to Powell.Kristin Hunt,\xa0Grace Christian: Hunt scored 14 points\xa0 and had six\xa0steals in the win against First Baptist Academy.Emma Harig, Heritage: Harig scored 13 points in the 64-42 win over Lenoir City.Kayla Romines, Heritage: Romines scored 17 points in the win against Lenoir City.Abby Wilson, Kingston: Wilson scored 20 points in the 74-45 win against Scott.Riley Guillemet, Kingston: Guillemet scored 21 points in the win against Scott and 23 points in the 48-37 win against Austin-East.Jordan Brewster, Lenoir City: Brewster scored 13 points in the 64-42 loss to Heritage.Campbell Penland, Northview: Penland scored 17 points and had three-3 pointers in the 47-31 win over\xa0Gatlinburg-Pittman.Taylor Cotner-Brabson, Northview:\xa0Cotner-Brabson scored\xa015 in the win against\xa0Gatlinburg-Pittman.Jada Guinn, Oak Ridge: Guinn scored 25 points in the 59-25 win against Anderson County and 24 points in the 66-38 win against Powell.Jaymi Golden, Oak Ridge: Golden scored 19 points in the win over Anderson County.Mykia Dowdell, Oak Ridge: Dowdell scored 25 points in the win against Powell.Morgan Hackworth, Oliver Springs: Hackworth scored 12 points in the 54-40 loss to Wartburg.Haley Schubert, Powell: Schubert scored 22 points\xa0in the 66-38 loss to Oak Ridge and 27 points in the 44-37 win against Halls.Kyra Stanley, Scott County: Stanley scored 12 points in the 58-28 loss to Alcoa.Chloe Yearwood, Tellico Plains: Yearwood scored 11 points and had three steals in the 54-32 win over Polk County.Jaden Hollinghead, Tellico Plains: Hollinghead scored 11 points\xa0in the win against Polk County.Samantha Russell, Tellico Plains: Russell scored 23 points and had nine rebounds\xa0in the win over Polk County.MarCreshia Phillips, Tennessee School for the Deaf: Phillips scored seven points in the 47-17 loss to Wasburn.Hannah Hurtt, Wartburg: Hurtt scored 16 points in the 54-40 win over Oliver Springs.Top performers can be submitted by coaches to prepxtra@knoxnews.com. This roundup includes games Wednesday through Friday.'

# %%
usa_df.loc[624, 'text']
# Out:
# 'A mother terrier with her\xa0litter of five-day-old puppies and\xa0a deaf dog named Hazel were among the 108 dogs and 17 cats that arrived in Salem Saturday from high-kill shelters in Oklahoma and will soon be up for adoption.This was the 16th flight organized by Fetch Fido a Flight, an\xa0organization that transports animals from those high-kill shelters to Oregon where they find a reprieve from euthanasia.Each flight costs about $17,000, paid for by donations. The organization hopes to grow to support one or two flights every month."Dogs are being euthanized because we can\'t get a plane out," said Carole Weber, board secretary of Fetch Fido a Flight. "(Oklahoma shelters) are so backed up, it\'s brutal."After landing in Salem, the cats and dogs were driven to SafeHaven Humane Society south of Albany. \xa0Contact the reporter at cradnovich@statesmanjournal.com or 503-399-6864, or follow him on Twitter at @CDRadnovich'

# %%
usa_df = usa_df.drop(523)
usa_df = usa_df.drop(624)

# %% [markdown]
# Next, we graphed the distributions of the variable subjectivity, where 0 is least subjective and 1 is most subjective, again split up by news source and with dotted lines to indicate the mean.

# %%
plt.subplot(2, 3, 1)
graph1 = sns.histplot(data=ap_df, x='subjectivity')
graph1.set_title("AP News Subjectivity")
graph1.axvline(ap_df['subjectivity'].mean(), color='#2e2e2e', linestyle='--')

plt.subplot(2, 3, 2)
graph2 = sns.histplot(data=guard_df, x='subjectivity')
graph2.set_title('Guardian News Subjectivity')
graph2.axvline(guard_df['subjectivity'].mean(), color='#2e2e2e', linestyle='--')

plt.subplot(2, 3, 3)
graph3 = sns.histplot(data=nyt_df, x='subjectivity')
graph3.set_title('New York Times Subjectivity')
graph3.axvline(nyt_df['subjectivity'].mean(), color='#2e2e2e', linestyle='--')

plt.subplot(2, 3, 4)
graph4 = sns.histplot(data=usa_df, x='subjectivity')
graph4.set_title('USA Today Subjectivity')
graph4.axvline(usa_df['subjectivity'].mean(), color='#2e2e2e', linestyle='--')


plt.subplot(2, 3, 5)
graph5 = sns.histplot(data=abc_df, x='subjectivity')
graph5.set_title('ABC News Subjectivity')
graph5.axvline(abc_df['subjectivity'].mean(), color='#2e2e2e', linestyle='--')

# %% [markdown]
# Looking at the subjectivity distributions, we again check for the most notable outliers and remove irrelevant articles to make the distribution curves more normal.

# %%
# AP News
ap_df[ap_df['subjectivity'] < 0.1]
# Out:
#                                                         headline  \
# 54  Ómicron trastoca el regreso a las escuelas en EEUU | AP News
#
#                         date source  \
# 54 2022-01-03 22:02:33+00:00     ap
#
#                                                                      url  \
# 54  https://apnews.com/article/noticias-cccc488dc1f210238013cd014571b909
#
#                                                                                                                                  text  \
# 54  Algunos sistemas escolares de Estados Unidos ampliaron sus vacaciones el lunes o volvieron a impartir clases por internet debi...
#
#     polarity  subjectivity
# 54       0.0           0.0

# %%
# remove because we are only considering articles in English
ap_df = ap_df.drop(54)

# %% [markdown]
# Next, we want to explore the relationship between polarity and subjectivity in different news sources by making line plots with a fitted regression line.

# %%
graph = sns.lmplot(x='polarity', y='subjectivity', col='source', data=combined_df, height=4, col_wrap=3)

# %% [markdown]
# ## Keyword frequencies

# %% [markdown]
# Another thing we explored with the data is finding frequencies of certain keywords relevant to our research, such as words for the Deaf community with positive connotations (hard of hearing, Deaf) and those with negative connotations (deaf, mute, hearing impaired).

# %%
# make a defaultdict holding all the articles in one string, separated by news source
# like a bag of words
allwords = defaultdict(lambda: "") # make a defaultdict where keys that you access are a given a default value

for i in range(len(df_list)):
    for article in df_list[i]['text']:
        allwords[i] += article
        
# allwords

# %%
searchList = ['deaf', 'Deaf', 'mute', 'deaf and dumb', 'hearing impaired', 'hard of hearing']  # our search words
freqsDict = {}    # will hold key, value pairs of (index of the source, frequency list of the terms in that specific source)

for i in range(len(allwords)):
    source = allwords[i]
    freqsList = []
    for term in searchList:
        freqsList.append(source.count(term))
    freqsDict[i] = freqsList

freqsDict
# Out:
# {0: [212, 55, 5, 4, 9, 12],
#  1: [444, 90, 8, 1, 25, 29],
#  2: [10037, 1852, 510, 87, 95, 411],
#  3: [5355, 1264, 96, 16, 94, 126],
#  4: [2335, 937, 40, 1, 92, 293]}

# %%
# turn freqsDict into a pandas DataFrame for easier reading
terms = pd.DataFrame(data=freqsDict)
terms.index = searchList
terms.columns = ['abc', 'ap', 'guard', 'nyt', 'usa']
terms
# Out:
#                   abc   ap  guard   nyt   usa
# deaf              212  444  10037  5355  2335
# Deaf               55   90   1852  1264   937
# mute                5    8    510    96    40
# deaf and dumb       4    1     87    16     1
# hearing impaired    9   25     95    94    92
# hard of hearing    12   29    411   126   293

# %%
# get how many words for each news source to proportionalize & account for the fact that some news sources have more articles
news_size = [len(allwords[i]) for i in allwords]
news_size
# Out:
# [680789, 994087, 42986118, 3674644, 6078857]

# %%
# proportionalize for each number in the dataframe
for i in range(len(terms.columns)):
    source = terms.columns[i]
    terms[source] = terms[source] / news_size[i]

terms
# Out:
#                        abc        ap     guard       nyt           usa
# deaf              0.000311  0.000447  0.000233  0.001457  3.841183e-04
# Deaf              0.000081  0.000091  0.000043  0.000344  1.541408e-04
# mute              0.000007  0.000008  0.000012  0.000026  6.580184e-06
# deaf and dumb     0.000006  0.000001  0.000002  0.000004  1.645046e-07
# hearing impaired  0.000013  0.000025  0.000002  0.000026  1.513442e-05
# hard of hearing   0.000018  0.000029  0.000010  0.000034  4.819985e-05

# %% [markdown]
# Next, we visualized these frequencies to see if there were any trends.

# %%
# visualization
plot_freqs = terms.plot(kind="barh", stacked=True, title="Frequencies of Phrases in Popular News Sources", colormap="plasma",
                       fontsize=15, subplots=True)

# %% [markdown]
# ## TF-IDF Exploration

# %% [markdown]
# ### Top Keywords

# %% [markdown]
# We can use TF-IDF techniques to extrapolate keywords from a text. We can see which words are the most impactful to given documents.
#
# We will be dividing our articles up into documents based on their news source and year they were published in.

# %%
# Dividing up our text data into combined strings by source and year
documents = defaultdict(lambda: defaultdict(str))

for _, _, _, source, _, text, _, _, year in combined_df.itertuples():
    documents[source][year] += text

# %% [markdown]
# We will be using the sklearn library to process these documents into their TF-IDFs, and need them in a list format.
#
# Here we convert our dictionary into a list of strings, and preserve the keys of the dictionary in a separate list called document_names

# %%
corpus = []
document_names = []
for source in documents.keys():
    for year in documents[source].keys():
        corpus.append(documents[source][year])
        document_names.append((source, year))

# %%
vectorizer = TfidfVectorizer(stop_words=stopwords.words('english'))
X = vectorizer.fit_transform(corpus)
words = list(vectorizer.get_feature_names_out())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25928/3843743456.py in <module>
#       1 vectorizer = TfidfVectorizer(stop_words=stopwords.words('english'))
#       2 X = vectorizer.fit_transform(corpus)
# ----> 3 words = list(vectorizer.get_feature_names_out())
#
# AttributeError: 'TfidfVectorizer' object has no attribute 'get_feature_names_out'

# %% [markdown]
# Now that we have our TF-IDFs in X, we want to look to see what the most significant words in each document are.
#
# Here we find the top 10 keywords for each document and add them into a new dictionary: top_tfidfs.

# %%
top_tfidfs = defaultdict(lambda: defaultdict(list))
for tfidfs, (source, year) in zip(X.toarray(), document_names):
    sorted_tfidfs = tfidfs.argsort()[:-11:-1]
    
    for index in sorted_tfidfs:
        top_tfidfs[source][year].append(words[index])

# %%
top_tfidfs['guard'][2021]

# %%
# Getting a list of all years present in our dataset
all_years = set()
for source in top_tfidfs.keys():
    all_years = all_years.union(set(top_tfidfs[source].keys()))
all_years = list(all_years)
all_years.sort()

# %% [markdown]
# Now that we have the top keywords for each source for each year, we can print them out. We decided to only print the top 5 keywords of each source in each year to keep the representation readable.

# %%
for year in all_years:
    print(f'\n--- Year {year} ---')
    for source in top_tfidfs.keys():
        if year in top_tfidfs[source]:
            print(f'{source}: {top_tfidfs[source][year][:5]}')

# %% [markdown]
# ### Importance of Keywords

# %% [markdown]
# We looked at the top keywords for entire years, but we might also want to track how significant different keywords are for all articles.
#
# For this we're going to have each article be a separate document in our corpus. We will then be able to graph the TF-IDF scores for different keywords over time.

# %%
corpus = []
for text in combined_df['text']:
    corpus.append(text)

# %%
vectorizer = TfidfVectorizer(stop_words=stopwords.words('english'))
X = vectorizer.fit_transform(corpus)

# %% [markdown]
# X is a sparse matrix where every document in our corpus is a row, and every column represents a word. There is a column for every different word in the corpus (around 150,000) and the value in a given column represents the TF-IDF value of the word for the given article. This is equivalent to the significance of the keyword in the article. If the keyword isn't present in an article the TF-IDF will just be 0.
#
# We start by getting the column index of different keywords we want to track

# %%
words = list(vectorizer.get_feature_names_out())

disabled_index = words.index('disabled')
culture_index = words.index('culture')
deaf_index = words.index('deaf')
cochlear_index = words.index('cochlear')
handicapped_index = words.index('handicapped')
art_index = words.index('art')

# %% [markdown]
# We can then take those columns and add them back into our dataframe

# %%
combined_df['disabled'] = X[:, disabled_index].toarray()
combined_df['culture'] = X[:, culture_index].toarray()
combined_df['deaf'] = X[:, deaf_index].toarray()
combined_df['cochlear'] = X[:, cochlear_index].toarray()
combined_df['handicapped'] = X[:, handicapped_index].toarray()
combined_df['art'] = X[:, art_index].toarray()

# %% [markdown]
# We can now graph the distribution of significance for each keyword

# %%
plt.subplot(2, 3, 1)
graph1 = sns.histplot(data=combined_df[combined_df['disabled'] > 0], x='disabled')
graph1.set_title("Disabled significance")
graph1.set_xlabel('Significance')
graph1.axvline(combined_df.loc[combined_df['disabled'] > 0, 'disabled'].mean(), color='#2e2e2e', linestyle='--')

plt.subplot(2, 3, 2)
graph2 = sns.histplot(data=combined_df[combined_df['culture'] > 0], x='culture')
graph2.set_title("Culture significance")
graph2.set_xlabel('Significance')
graph2.axvline(combined_df.loc[combined_df['culture'] > 0, 'culture'].mean(), color='#2e2e2e', linestyle='--')

plt.subplot(2, 3, 3)
graph3 = sns.histplot(data=combined_df[combined_df['deaf'] > 0], x='deaf')
graph3.set_title("Deaf significance")
graph3.set_xlabel('Significance')
graph3.axvline(combined_df.loc[combined_df['deaf'] > 0, 'deaf'].mean(), color='#2e2e2e', linestyle='--')

plt.subplot(2, 3, 4)
graph4 = sns.histplot(data=combined_df[combined_df['cochlear'] > 0], x='cochlear')
graph4.set_title("Cochlear significance")
graph4.set_xlabel('Significance')
graph4.axvline(combined_df.loc[combined_df['cochlear'] > 0, 'cochlear'].mean(), color='#2e2e2e', linestyle='--')

plt.subplot(2, 3, 5)
graph5 = sns.histplot(data=combined_df[combined_df['handicapped'] > 0], x='handicapped')
graph5.set_title("Handicapped significance")
graph5.set_xlabel('Significance')
graph5.axvline(combined_df.loc[combined_df['handicapped'] > 0, 'handicapped'].mean(), color='#2e2e2e', linestyle='--')

plt.subplot(2, 3, 6)
graph6 = sns.histplot(data=combined_df[combined_df['art'] > 0], x='art')
graph6.set_title("Art significance")
graph6.set_xlabel('Significance')
graph6.axvline(combined_df.loc[combined_df['art'] > 0, 'art'].mean(), color='#2e2e2e', linestyle='--')

# %% [markdown]
# It appears as though the significance distribution for each keyword is fairly similar. Handicapped, cochlear, and disabled stand out as having more significance generally when they appear.

# %% [markdown]
# We can also check the significance of each term over time

# %%
plt.subplot(2, 3, 1)
graph1 = sns.lineplot(data=combined_df, x='year', y='disabled')
graph1.set_title("Disabled significance over time")
graph1.set_ylabel('Significance')

plt.subplot(2, 3, 2)
graph2 = sns.lineplot(data=combined_df, x='year', y='culture')
graph2.set_title("Culture significance over time")
graph2.set_ylabel('Significance')

plt.subplot(2, 3, 3)
graph3 = sns.lineplot(data=combined_df, x='year', y='deaf')
graph3.set_title("Deaf significance over time")
graph3.set_ylabel('Significance')

plt.subplot(2, 3, 4)
graph4 = sns.lineplot(data=combined_df, x='year', y='cochlear')
graph4.set_title("Cochlear significance over time")
graph4.set_ylabel('Significance')

plt.subplot(2, 3, 5)
graph5 = sns.lineplot(data=combined_df, x='year', y='handicapped')
graph5.set_title("Handicapped significance over time")
graph5.set_ylabel('Significance')

plt.subplot(2, 3, 6)
graph6 = sns.lineplot(data=combined_df, x='year', y='art')
graph6.set_title("Art significance over time")
graph6.set_ylabel('Significance')

# %% [markdown]
# Disabled as a keyword is interesting in how it grew in signifiance until around 2013 at which point it began waning in significance. A similar phenomenon has appeared to happen with art as a keyword.
#
# Culture appears to have spiked in significance in the early 1990s and to then have settled into a higher plateau of significance since then.
#
# Cochlear and handicapped both appear to be dominated by a handful of articles before 2000 and to have had little significance since.
#
# Finally deaf as a keyword had a major fall in significance in 2000, but since then has appeared to have had a slow growth in significance.

# %% [markdown]
# One final comparison of keyword significance is to see if there is any correlation between significance for different keywords

# %%
fig1 = pd.plotting.scatter_matrix(frame=combined_df[['disabled', 'culture', 'deaf', 'cochlear', 'handicapped', 'art']])

# %% [markdown]
# # Ethics & Privacy

# %% [markdown]
# Our project will use publicly available news articles from a variety of news sources.
#
# With our project, we are aware of many biases that may impact our results. First of all, because our project is surrounding Deafness, and we are all hearing, we have an innate hearing bias that may influence our perspective on different aspects of this project and potentially our interpretations of the results. We also acknowledge that, due to the nature of this project, as supporters of the Deaf community we subsequently have a pro-Deafness bias that could impact a sentiment analysis because of the data we collect or how we interpret that data. Additionally, if we conduct the sentiment analysis with the help of a library, there is a possibility that this library was made by an able-bodied individual, which may influence the results of the sentiment analysis when looking at the sentiment of the language surrounding Deafness.
#
# When collecting the news article data, we also are aware that the choices of news databases may influence the results of the sentiment analysis, since some news sources may be more likely to have a positive or negative sentiment on this subject. We will attempt to counter this by selecting a variety of varying news sources to have a more comprehensive dataset. We also are aware that we may have to conduct data normalization, since some news sources may have more related articles than others and therefore may skew the sentiment results.
#
# Acknowledging these biases allows us to look at the results of our analysis through a more critical lens. With them in mind, we will better be able to conduct this analysis since we can actively reflect on each step in case our biases are influencing our work.

# %% [markdown]
# # Conclusion & Discussion

# %% [markdown]
# *Fill in your discussion information here*

# %% [markdown]
# # Team Contributions

# %% [markdown]
# *Specify who in your group worked on which parts of the project.*
